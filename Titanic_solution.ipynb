# %% [markdown]
# <a href="https://colab.research.google.com/github/Cazzarooo/Titanic_solution/blob/main/Titanic_solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('titanic.csv')

# %%
filter1 = df[['Name', 'Age', 'Sex', 'Pclass', 'Survived']]
filter1
# Out:
#                                                   Name   Age     Sex  Pclass  \
# 0                              Braund, Mr. Owen Harris  22.0    male       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female       1
# 2                               Heikkinen, Miss. Laina  26.0  female       3
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female       1
# 4                             Allen, Mr. William Henry  35.0    male       3
# ..                                                 ...   ...     ...     ...
# 886                              Montvila, Rev. Juozas  27.0    male       2
# 887                       Graham, Miss. Margaret Edith  19.0  female       1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  female       3
# 889                              Behr, Mr. Karl Howell  26.0    male       1
# 890                                Dooley, Mr. Patrick  32.0    male       3
#
#      Survived
# 0           0
# ...

# %%
filter1 = filter1.loc[(filter1['Sex'] == 'female') & (filter1['Pclass'] == 1) & (filter1['Survived'] == 1) ]
filter1
# Out:
#                                                   Name   Age     Sex  Pclass  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  female       1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  female       1
# 11                            Bonnell, Miss. Elizabeth  58.0  female       1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)   NaN  female       1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  49.0  female       1
# ..                                                 ...   ...     ...     ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  45.0  female       1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  48.0  female       1
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  47.0  female       1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0  female       1
# 887                       Graham, Miss. Margaret Edith  19.0  female       1
#
#      Survived
# 1           1
# ...

# %%
filter1 = filter1.sort_values(by=['Name'])
filter1
# Out:
#                                                   Name   Age     Sex  Pclass  \
# 730                      Allen, Miss. Elisabeth Walton  29.0  female       1
# 275                  Andrews, Miss. Kornelia Theodosia  63.0  female       1
# 571      Appleton, Mrs. Edward Dale (Charlotte Lamson)  53.0  female       1
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18.0  female       1
# 369                      Aubart, Mme. Leontine Pauline  24.0  female       1
# ..                                                 ...   ...     ...     ...
# 258                                   Ward, Miss. Anna  35.0  female       1
# 366   Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  60.0  female       1
# 318                           Wick, Miss. Mary Natalie  31.0  female       1
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  45.0  female       1
# 325                           Young, Miss. Marie Grice  36.0  female       1
#
#      Survived
# 730         1
# ...

# %%
filter1.to_csv('titanic_result.csv', index = False)
